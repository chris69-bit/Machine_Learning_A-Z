# %%
# Import Libraries
import pandas as pd
import numpy as np
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import VotingClassifier
from sklearn.pipeline import Pipeline

from category_encoders import CatBoostEncoder
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
import optuna
# Out:
# /kaggle/input/titanic/train.csv
# /kaggle/input/titanic/test.csv
# /kaggle/input/titanic/gender_submission.csv

# %% [markdown]
# # Import Dataset

# %%
df_train = pd.read_csv('/kaggle/input/titanic/train.csv')
df_train.head()
#df_train.describe()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_test = pd.read_csv('/kaggle/input/titanic/test.csv')
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# # Setting Features and Label

# %%
X = df_train.drop(columns=['PassengerId', 'Name', 'Survived'])
y = df_train['Survived']
X.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0       3    male  22.0      1      0         A/5 21171   7.2500   NaN
# 1       1  female  38.0      1      0          PC 17599  71.2833   C85
# 2       3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3       1  female  35.0      1      0            113803  53.1000  C123
# 4       3    male  35.0      0      0            373450   8.0500   NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %% [markdown]
# # Test Set#

# %%
test_Id = df_test['PassengerId']
test_df = df_test.drop(columns=['PassengerId', 'Name'])
test_df.head()
#X_df_test.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0       3    male  34.5      0      0   330911   7.8292   NaN        Q
# 1       3  female  47.0      1      0   363272   7.0000   NaN        S
# 2       2    male  62.0      0      0   240276   9.6875   NaN        Q
# 3       3    male  27.0      0      0   315154   8.6625   NaN        S
# 4       3  female  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# # Misisng Values

# %%
numerical_columns = X.select_dtypes(include=[np.number]).columns
categorical_columns = X.select_dtypes(include=['object']).columns

X[numerical_columns] = X[numerical_columns].fillna(-1)
X[categorical_columns] = X[categorical_columns].fillna("No Attribute")

test_df[numerical_columns] = test_df[numerical_columns].fillna(-1)
test_df[categorical_columns] = test_df[categorical_columns].fillna("No Attribute")

# %% [markdown]
# # Split The Training Data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# # Defining Preprocessing Steps

# %%
numeric_transformers = Pipeline(steps=[('scaling', StandardScaler())])
categorical_transformers = Pipeline(steps=[('catboosting', CatBoostEncoder(cols=categorical_columns, random_state=0))])
preprocessor = ColumnTransformer(transformers=[('num', numeric_transformers, numerical_columns),
                                               ('cat', categorical_transformers, categorical_columns)])

# %% [markdown]
# # Define Optuna

# %%
def objective(trial):
    xgb_params = {
        "learning_rate": trial.suggest_float("xgb_learning_rate",0.0001,0.1, log=True),
        "max_depth": trial.suggest_int("xgb_max_depth",3,12),
        "subsample": trial.suggest_float("xgb_subsample",0.5,1.0),
        "colsample_bytree": trial.suggest_float("xgb_colsample_bytree",0.5,1.0),
        "n_estimators": trial.suggest_int("xgb_n_estimators",50,300),
    }

    cat_params = {
        "learning_rate": trial.suggest_float("cat_learning_rate",0.0001,0.1, log=True),
        "depth": trial.suggest_int("cat_depth",3,10),
        "iterations": trial.suggest_int("cat_iterations",100,500),
        "l2_leaf_reg": trial.suggest_float("cat_l2_leaf_reg",0.0001,0.1, log=True),
        "subsample": trial.suggest_float("cat_subsample",0.5,1.0),
        "random_strength": trial.suggest_float("cat_random_strength",0.0001,0.1),
        
    }
    # Creating the Classifiers
    xgb = XGBClassifier(**xgb_params, use_label_encoder=False, eval_metric='logloss')
    cat = CatBoostClassifier(**cat_params, verbose=0)

    #Creating a Voting Classifier
    pipeline= Pipeline([('preprocessor', preprocessor),
                        ('voting_classifier', VotingClassifier(estimators=[('xgb',xgb),('cat',cat)], voting='hard'))])
    #Perfoming Cross_validation
    score = cross_val_score(pipeline, X_train, y_train, cv=5, scoring='accuracy').mean()
    return score

# %% [markdown]
# # Running Optuna Optimizer

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

#Getting the best parameters
best_params = study.best_params
print(best_params)
# Out:
# [I 2025-03-16 12:24:27,671] A new study created in memory with name: no-name-639b1d07-b84f-4423-a1a4-945a35a1c944
# [I 2025-03-16 12:24:32,469] Trial 0 finished with value: 0.8145671230178271 and parameters: {'xgb_learning_rate': 0.09637188502123784, 'xgb_max_depth': 12, 'xgb_subsample': 0.8496111933914645, 'xgb_colsample_bytree': 0.9229776863096839, 'xgb_n_estimators': 227, 'cat_learning_rate': 0.0015784550158023034, 'cat_depth': 7, 'cat_iterations': 315, 'cat_l2_leaf_reg': 0.00015594707927699567, 'cat_subsample': 0.5743429424915091, 'cat_random_strength': 0.07888821468614414}. Best is trial 0 with value: 0.8145671230178271.
# [I 2025-03-16 12:24:35,333] Trial 1 finished with value: 0.8047276666994977 and parameters: {'xgb_learning_rate': 0.007988972181996224, 'xgb_max_depth': 10, 'xgb_subsample': 0.7130754320146284, 'xgb_colsample_bytree': 0.9254627252780638, 'xgb_n_estimators': 235, 'cat_learning_rate': 0.0010893559454883712, 'cat_depth': 5, 'cat_iterations': 205, 'cat_l2_leaf_reg': 0.012249361184044395, 'cat_subsample': 0.7732348055776852, 'cat_random_strength': 0.029202673646288993}. Best is trial 0 with value: 0.8145671230178271.
# [I 2025-03-16 12:24:42,737] Trial 2 finished with value: 0.7878558061656653 and parameters: {'xgb_learning_rate': 0.009754265605175321, 'xgb_max_depth': 9, 'xgb_subsample': 0.6592703315799092, 'xgb_colsample_bytree': 0.7084113490830746, 'xgb_n_estimators': 138, 'cat_learning_rate': 0.00027248686273350205, 'cat_depth': 9, 'cat_iterations': 241, 'cat_l2_leaf_reg': 0.001338623858659889, 'cat_subsample': 0.8710268844532869, 'cat_random_strength': 0.07539241516817602}. Best is trial 0 with value: 0.8145671230178271.
# [I 2025-03-16 12:24:44,351] Trial 3 finished with value: 0.8047276666994977 and parameters: {'xgb_learning_rate': 0.0073245290426961, 'xgb_max_depth': 4, 'xgb_subsample': 0.5629975900721645, 'xgb_colsample_bytree': 0.7950731301887708, 'xgb_n_estimators': 291, 'cat_learning_rate': 0.00035216033132571346, 'cat_depth': 5, 'cat_iterations': 121, 'cat_l2_leaf_reg': 0.00022212467941163183, 'cat_subsample': 0.7278427528485809, 'cat_random_strength': 0.04869793820813608}. Best is trial 0 with value: 0.8145671230178271.
# [I 2025-03-16 12:24:48,651] Trial 4 finished with value: 0.8047375160051216 and parameters: {'xgb_learning_rate': 0.006158351513819897, 'xgb_max_depth': 5, 'xgb_subsample': 0.8258867860447703, 'xgb_colsample_bytree': 0.9460361569561813, 'xgb_n_estimators': 250, 'cat_learning_rate': 0.0012399869527921865, 'cat_depth': 4, 'cat_iterations': 254, 'cat_l2_leaf_reg': 0.0033126138921695833, 'cat_subsample': 0.6604076946345024, 'cat_random_strength': 0.07815198593706854}. Best is trial 0 with value: 0.8145671230178271.
# [I 2025-03-16 12:24:52,159] Trial 5 finished with value: 0.7962769624741456 and parameters: {'xgb_learning_rate': 0.004049543267695005, 'xgb_max_depth': 7, 'xgb_subsample': 0.8928762646682824, 'xgb_colsample_bytree': 0.6355982702472328, 'xgb_n_estimators': 244, 'cat_learning_rate': 0.00035343194865852204, 'cat_depth': 4, 'cat_iterations': 467, 'cat_l2_leaf_reg': 0.010367963454220494, 'cat_subsample': 0.5087792048496056, 'cat_random_strength': 0.010561849712143894}. Best is trial 0 with value: 0.8145671230178271.
# [I 2025-03-16 12:25:02,151] Trial 6 finished with value: 0.7977051117896189 and parameters: {'xgb_learning_rate': 0.012131387745021725, 'xgb_max_depth': 4, 'xgb_subsample': 0.9730267307958642, 'xgb_colsample_bytree': 0.634190615216873, 'xgb_n_estimators': 120, 'cat_learning_rate': 0.008410940779370954, 'cat_depth': 10, 'cat_iterations': 213, 'cat_l2_leaf_reg': 0.0011242150639759908, 'cat_subsample': 0.9869656293245754, 'cat_random_strength': 0.028327514638707658}. Best is trial 0 with value: 0.8145671230178271.
# [I 2025-03-16 12:25:10,501] Trial 7 finished with value: 0.6165763813651137 and parameters: {'xgb_learning_rate': 0.00029581402579707475, 'xgb_max_depth': 9, 'xgb_subsample': 0.9622989970370585, 'xgb_colsample_bytree': 0.7368451910072555, 'xgb_n_estimators': 211, 'cat_learning_rate': 0.0007551689310309942, 'cat_depth': 8, 'cat_iterations': 455, 'cat_l2_leaf_reg': 0.007932777462694794, 'cat_subsample': 0.9722974792589405, 'cat_random_strength': 0.04828724115727024}. Best is trial 0 with value: 0.8145671230178271.
# [I 2025-03-16 12:25:14,056] Trial 8 finished with value: 0.8047473653107456 and parameters: {'xgb_learning_rate': 0.025740823952539602, 'xgb_max_depth': 11, 'xgb_subsample': 0.9175598199349224, 'xgb_colsample_bytree': 0.588152964674499, 'xgb_n_estimators': 68, 'cat_learning_rate': 0.0002848222811742254, 'cat_depth': 6, 'cat_iterations': 380, 'cat_l2_leaf_reg': 0.03768818724411037, 'cat_subsample': 0.885079623095439, 'cat_random_strength': 0.0843298438849464}. Best is trial 0 with value: 0.8145671230178271.
# [I 2025-03-16 12:25:16,555] Trial 9 finished with value: 0.6165763813651137 and parameters: {'xgb_learning_rate': 0.0014589729209271687, 'xgb_max_depth': 4, 'xgb_subsample': 0.9255373585512995, 'xgb_colsample_bytree': 0.540841369009277, 'xgb_n_estimators': 57, 'cat_learning_rate': 0.0029623700371290305, 'cat_depth': 5, 'cat_iterations': 319, 'cat_l2_leaf_reg': 0.025877224285463872, 'cat_subsample': 0.9307651131707382, 'cat_random_strength': 0.09105045397011703}. Best is trial 0 with value: 0.8145671230178271.
# [I 2025-03-16 12:25:22,746] Trial 10 finished with value: 0.8061262680980992 and parameters: {'xgb_learning_rate': 0.0838341870446066, 'xgb_max_depth': 12, 'xgb_subsample': 0.808533239197245, 'xgb_colsample_bytree': 0.846669519437006, 'xgb_n_estimators': 176, 'cat_learning_rate': 0.08827648719012075, 'cat_depth': 7, 'cat_iterations': 355, 'cat_l2_leaf_reg': 0.00014849028021526867, 'cat_subsample': 0.5087546303348589, 'cat_random_strength': 0.06722016877893117}. Best is trial 0 with value: 0.8145671230178271.
# [I 2025-03-16 12:25:27,469] Trial 11 finished with value: 0.8131586723136017 and parameters: {'xgb_learning_rate': 0.05620346328455406, 'xgb_max_depth': 12, 'xgb_subsample': 0.8011670218765551, 'xgb_colsample_bytree': 0.8629453290602076, 'xgb_n_estimators': 167, 'cat_learning_rate': 0.07918585907883079, 'cat_depth': 7, 'cat_iterations': 351, 'cat_l2_leaf_reg': 0.00011650127699254683, 'cat_subsample': 0.5036639222681, 'cat_random_strength': 0.0682820501271708}. Best is trial 0 with value: 0.8145671230178271.
# [I 2025-03-16 12:25:32,561] Trial 12 finished with value: 0.8131488230079779 and parameters: {'xgb_learning_rate': 0.07701964583088976, 'xgb_max_depth': 12, 'xgb_subsample': 0.799195057801216, 'xgb_colsample_bytree': 0.8759833700766733, 'xgb_n_estimators': 179, 'cat_learning_rate': 0.023515578120477873, 'cat_depth': 7, 'cat_iterations': 398, 'cat_l2_leaf_reg': 0.00037475650068361855, 'cat_subsample': 0.6046258124617063, 'cat_random_strength': 0.062368467919541114}. Best is trial 0 with value: 0.8145671230178271.
# [I 2025-03-16 12:25:37,737] Trial 13 finished with value: 0.8089333202009259 and parameters: {'xgb_learning_rate': 0.043141066530330334, 'xgb_max_depth': 7, 'xgb_subsample': 0.7086048460503142, 'xgb_colsample_bytree': 0.9859359379178728, 'xgb_n_estimators': 131, 'cat_learning_rate': 0.08475495942955959, 'cat_depth': 8, 'cat_iterations': 290, 'cat_l2_leaf_reg': 0.00012649249363933874, 'cat_subsample': 0.5917657075969995, 'cat_random_strength': 0.09795552307383591}. Best is trial 0 with value: 0.8145671230178271.
# [I 2025-03-16 12:25:46,068] Trial 14 finished with value: 0.7556288781640894 and parameters: {'xgb_learning_rate': 0.0012516053232467872, 'xgb_max_depth': 10, 'xgb_subsample': 0.8461992963118712, 'xgb_colsample_bytree': 0.8393074719470306, 'xgb_n_estimators': 300, 'cat_learning_rate': 0.007319359843037296, 'cat_depth': 8, 'cat_iterations': 423, 'cat_l2_leaf_reg': 0.0007627178134041366, 'cat_subsample': 0.578768583717063, 'cat_random_strength': 0.0636575784548099}. Best is trial 0 with value: 0.8145671230178271.
# [I 2025-03-16 12:25:49,943] Trial 15 finished with value: 0.8117403723037526 and parameters: {'xgb_learning_rate': 0.02614377558307831, 'xgb_max_depth': 12, 'xgb_subsample': 0.7443014186804566, 'xgb_colsample_bytree': 0.9020984983174699, 'xgb_n_estimators': 204, 'cat_learning_rate': 0.017789914628401075, 'cat_depth': 6, 'cat_iterations': 326, 'cat_l2_leaf_reg': 0.00043833824053038167, 'cat_subsample': 0.6694138441378148, 'cat_random_strength': 0.05477820122103506}. Best is trial 0 with value: 0.8145671230178271.
# [I 2025-03-16 12:25:52,721] Trial 16 finished with value: 0.8005220131980696 and parameters: {'xgb_learning_rate': 0.09983364152034081, 'xgb_max_depth': 8, 'xgb_subsample': 0.5823281347247137, 'xgb_colsample_bytree': 0.9938362563141163, 'xgb_n_estimators': 104, 'cat_learning_rate': 0.00011265653415256159, 'cat_depth': 3, 'cat_iterations': 136, 'cat_l2_leaf_reg': 0.00011493269162938563, 'cat_subsample': 0.5417945620343021, 'cat_random_strength': 0.03598207318864101}. Best is trial 0 with value: 0.8145671230178271.
# [I 2025-03-16 12:26:06,159] Trial 17 finished with value: 0.8145572737122032 and parameters: {'xgb_learning_rate': 0.028694103200319114, 'xgb_max_depth': 11, 'xgb_subsample': 0.6481503410844176, 'xgb_colsample_bytree': 0.7883486014297587, 'xgb_n_estimators': 156, 'cat_learning_rate': 0.003582044233188006, 'cat_depth': 10, 'cat_iterations': 289, 'cat_l2_leaf_reg': 0.08159237307050585, 'cat_subsample': 0.658324021823485, 'cat_random_strength': 0.07318058007011519}. Best is trial 0 with value: 0.8145671230178271.
# [I 2025-03-16 12:26:19,340] Trial 18 finished with value: 0.8145375751009555 and parameters: {'xgb_learning_rate': 0.021522987036537242, 'xgb_max_depth': 10, 'xgb_subsample': 0.5015851117850951, 'xgb_colsample_bytree': 0.8019042628687503, 'xgb_n_estimators': 266, 'cat_learning_rate': 0.00316565316175125, 'cat_depth': 10, 'cat_iterations': 274, 'cat_l2_leaf_reg': 0.06791397288458557, 'cat_subsample': 0.7688205818561734, 'cat_random_strength': 0.08812782783025926}. Best is trial 0 with value: 0.8145671230178271.
# [I 2025-03-16 12:26:25,645] Trial 19 finished with value: 0.6165763813651137 and parameters: {'xgb_learning_rate': 0.00013582186255236764, 'xgb_max_depth': 6, 'xgb_subsample': 0.648254712475075, 'xgb_colsample_bytree': 0.6772940934707404, 'xgb_n_estimators': 209, 'cat_learning_rate': 0.0026041408130784245, 'cat_depth': 9, 'cat_iterations': 168, 'cat_l2_leaf_reg': 0.002835535467083465, 'cat_subsample': 0.6595527578298412, 'cat_random_strength': 0.09912328970321421}. Best is trial 0 with value: 0.8145671230178271.
# [I 2025-03-16 12:26:34,241] Trial 20 finished with value: 0.6165763813651137 and parameters: {'xgb_learning_rate': 0.0012926136953153758, 'xgb_max_depth': 11, 'xgb_subsample': 0.6304174419974793, 'xgb_colsample_bytree': 0.7759197709282737, 'xgb_n_estimators': 154, 'cat_learning_rate': 0.0062019223455134125, 'cat_depth': 9, 'cat_iterations': 300, 'cat_l2_leaf_reg': 0.07629292662194304, 'cat_subsample': 0.7120726140519716, 'cat_random_strength': 0.08086364537102567}. Best is trial 0 with value: 0.8145671230178271.
# [I 2025-03-16 12:26:47,699] Trial 21 finished with value: 0.8117502216093765 and parameters: {'xgb_learning_rate': 0.02233090957746329, 'xgb_max_depth': 10, 'xgb_subsample': 0.5249139757345572, 'xgb_colsample_bytree': 0.8108922502592669, 'xgb_n_estimators': 270, 'cat_learning_rate': 0.0016700801026024723, 'cat_depth': 10, 'cat_iterations': 271, 'cat_l2_leaf_reg': 0.09800210542601688, 'cat_subsample': 0.7810587514342388, 'cat_random_strength': 0.08780905695536642}. Best is trial 0 with value: 0.8145671230178271.
# [I 2025-03-16 12:26:59,712] Trial 22 finished with value: 0.8131488230079779 and parameters: {'xgb_learning_rate': 0.03551692040533545, 'xgb_max_depth': 11, 'xgb_subsample': 0.5141263854063655, 'xgb_colsample_bytree': 0.7541976955924901, 'xgb_n_estimators': 272, 'cat_learning_rate': 0.004222266253665776, 'cat_depth': 10, 'cat_iterations': 219, 'cat_l2_leaf_reg': 0.03858405695837531, 'cat_subsample': 0.8260151578575357, 'cat_random_strength': 0.07490263743187829}. Best is trial 0 with value: 0.8145671230178271.
# [I 2025-03-16 12:27:08,204] Trial 23 finished with value: 0.8061262680980992 and parameters: {'xgb_learning_rate': 0.014745326866140555, 'xgb_max_depth': 9, 'xgb_subsample': 0.5980924292411629, 'xgb_colsample_bytree': 0.8112316110824541, 'xgb_n_estimators': 225, 'cat_learning_rate': 0.016462987892268077, 'cat_depth': 9, 'cat_iterations': 282, 'cat_l2_leaf_reg': 0.021258440620899422, 'cat_subsample': 0.6282474809622507, 'cat_random_strength': 0.0910272127321276}. Best is trial 0 with value: 0.8145671230178271.
# [I 2025-03-16 12:27:23,454] Trial 24 finished with value: 0.8201615286122328 and parameters: {'xgb_learning_rate': 0.04715531384031086, 'xgb_max_depth': 11, 'xgb_subsample': 0.6842012541367772, 'xgb_colsample_bytree': 0.7063265941151023, 'xgb_n_estimators': 264, 'cat_learning_rate': 0.002058033302219121, 'cat_depth': 10, 'cat_iterations': 316, 'cat_l2_leaf_reg': 0.05716294723972189, 'cat_subsample': 0.7103322975984013, 'cat_random_strength': 0.05574267025961141}. Best is trial 24 with value: 0.8201615286122328.
# [I 2025-03-16 12:27:31,240] Trial 25 finished with value: 0.813138973702354 and parameters: {'xgb_learning_rate': 0.05281149108449092, 'xgb_max_depth': 11, 'xgb_subsample': 0.7083101101348955, 'xgb_colsample_bytree': 0.6894942164079598, 'xgb_n_estimators': 193, 'cat_learning_rate': 0.000705722080680652, 'cat_depth': 8, 'cat_iterations': 343, 'cat_l2_leaf_reg': 0.004703400523044013, 'cat_subsample': 0.6948290767540567, 'cat_random_strength': 0.056724366931478996}. Best is trial 24 with value: 0.8201615286122328.
# [I 2025-03-16 12:27:41,997] Trial 26 finished with value: 0.636215896779277 and parameters: {'xgb_learning_rate': 0.0031334625497129375, 'xgb_max_depth': 8, 'xgb_subsample': 0.7706726374720207, 'xgb_colsample_bytree': 0.7257363111412376, 'xgb_n_estimators': 90, 'cat_learning_rate': 0.001902771517579557, 'cat_depth': 9, 'cat_iterations': 386, 'cat_l2_leaf_reg': 0.04246787512687782, 'cat_subsample': 0.567592426219808, 'cat_random_strength': 0.04120621494946629}. Best is trial 24 with value: 0.8201615286122328.
# [I 2025-03-16 12:27:57,344] Trial 27 finished with value: 0.8173544765094063 and parameters: {'xgb_learning_rate': 0.04418710735139118, 'xgb_max_depth': 11, 'xgb_subsample': 0.8713954507989332, 'xgb_colsample_bytree': 0.6441877240719135, 'xgb_n_estimators': 223, 'cat_learning_rate': 0.0007445860736223092, 'cat_depth': 10, 'cat_iterations': 316, 'cat_l2_leaf_reg': 0.02210987503584394, 'cat_subsample': 0.6194223797435128, 'cat_random_strength': 0.07237278035632407}. Best is trial 24 with value: 0.8201615286122328.
# [I 2025-03-16 12:28:10,215] Trial 28 finished with value: 0.8075347188023244 and parameters: {'xgb_learning_rate': 0.056439004590551095, 'xgb_max_depth': 12, 'xgb_subsample': 0.8680126614279501, 'xgb_colsample_bytree': 0.631143010367272, 'xgb_n_estimators': 224, 'cat_learning_rate': 0.0006309679987854719, 'cat_depth': 9, 'cat_iterations': 423, 'cat_l2_leaf_reg': 0.018015823447581424, 'cat_subsample': 0.6130161421987776, 'cat_random_strength': 0.012215514254288892}. Best is trial 24 with value: 0.8201615286122328.
# [I 2025-03-16 12:28:14,345] Trial 29 finished with value: 0.8033192159952722 and parameters: {'xgb_learning_rate': 0.013615024300980673, 'xgb_max_depth': 10, 'xgb_subsample': 0.7427276651636806, 'xgb_colsample_bytree': 0.5085261679874126, 'xgb_n_estimators': 252, 'cat_learning_rate': 0.0012998844434414035, 'cat_depth': 6, 'cat_iterations': 316, 'cat_l2_leaf_reg': 0.007162136312202823, 'cat_subsample': 0.5448386095144705, 'cat_random_strength': 0.057332429993112284}. Best is trial 24 with value: 0.8201615286122328.
# [I 2025-03-16 12:28:23,544] Trial 30 finished with value: 0.8103417709051512 and parameters: {'xgb_learning_rate': 0.09643281205518163, 'xgb_max_depth': 9, 'xgb_subsample': 0.8667672791722865, 'xgb_colsample_bytree': 0.5843448550862127, 'xgb_n_estimators': 236, 'cat_learning_rate': 0.00015542398656229236, 'cat_depth': 8, 'cat_iterations': 491, 'cat_l2_leaf_reg': 0.014260646641056841, 'cat_subsample': 0.7446099346697993, 'cat_random_strength': 0.02653579278719453}. Best is trial 24 with value: 0.8201615286122328.
# [I 2025-03-16 12:28:37,315] Trial 31 finished with value: 0.8089530188121739 and parameters: {'xgb_learning_rate': 0.032451511357653395, 'xgb_max_depth': 11, 'xgb_subsample': 0.7007988803310389, 'xgb_colsample_bytree': 0.6662312933778821, 'xgb_n_estimators': 196, 'cat_learning_rate': 0.0008004447426121497, 'cat_depth': 10, 'cat_iterations': 252, 'cat_l2_leaf_reg': 0.04903068285783876, 'cat_subsample': 0.6265475148386105, 'cat_random_strength': 0.07077688462159995}. Best is trial 24 with value: 0.8201615286122328.
# [I 2025-03-16 12:28:54,698] Trial 32 finished with value: 0.8117502216093765 and parameters: {'xgb_learning_rate': 0.048236777816519964, 'xgb_max_depth': 11, 'xgb_subsample': 0.6722551340132292, 'xgb_colsample_bytree': 0.9486100684903578, 'xgb_n_estimators': 156, 'cat_learning_rate': 0.004696461579895155, 'cat_depth': 10, 'cat_iterations': 367, 'cat_l2_leaf_reg': 0.06619078073959903, 'cat_subsample': 0.6789817826442712, 'cat_random_strength': 0.07358194763391299}. Best is trial 24 with value: 0.8201615286122328.
# [I 2025-03-16 12:29:05,083] Trial 33 finished with value: 0.8131586723136017 and parameters: {'xgb_learning_rate': 0.018422381646890553, 'xgb_max_depth': 10, 'xgb_subsample': 0.6177972303988739, 'xgb_colsample_bytree': 0.5951820439975268, 'xgb_n_estimators': 227, 'cat_learning_rate': 0.0020418373322341264, 'cat_depth': 9, 'cat_iterations': 329, 'cat_l2_leaf_reg': 0.02513271519469333, 'cat_subsample': 0.636572302412647, 'cat_random_strength': 0.062205954912662745}. Best is trial 24 with value: 0.8201615286122328.
# [I 2025-03-16 12:29:17,526] Trial 34 finished with value: 0.8005023145868215 and parameters: {'xgb_learning_rate': 0.00877953601258455, 'xgb_max_depth': 3, 'xgb_subsample': 0.6738365586412585, 'xgb_colsample_bytree': 0.7133052708741924, 'xgb_n_estimators': 284, 'cat_learning_rate': 0.000470214977256403, 'cat_depth': 10, 'cat_iterations': 245, 'cat_l2_leaf_reg': 0.09855207537620767, 'cat_subsample': 0.7153515529328737, 'cat_random_strength': 0.07959636897973084}. Best is trial 24 with value: 0.8201615286122328.
# [I 2025-03-16 12:29:20,160] Trial 35 finished with value: 0.8019107652910469 and parameters: {'xgb_learning_rate': 0.004984958851434946, 'xgb_max_depth': 12, 'xgb_subsample': 0.7695522349126654, 'xgb_colsample_bytree': 0.7629590826982712, 'xgb_n_estimators': 257, 'cat_learning_rate': 0.0012114943045303335, 'cat_depth': 5, 'cat_iterations': 190, 'cat_l2_leaf_reg': 0.0025980999552605555, 'cat_subsample': 0.8037704499507446, 'cat_random_strength': 0.04849556081317944}. Best is trial 24 with value: 0.8201615286122328.
# [I 2025-03-16 12:29:29,260] Trial 36 finished with value: 0.8145769723234512 and parameters: {'xgb_learning_rate': 0.06705319640865273, 'xgb_max_depth': 11, 'xgb_subsample': 0.9205945949146431, 'xgb_colsample_bytree': 0.9137202808522572, 'xgb_n_estimators': 144, 'cat_learning_rate': 0.010764931646591583, 'cat_depth': 9, 'cat_iterations': 301, 'cat_l2_leaf_reg': 0.029857807453863325, 'cat_subsample': 0.6512348016713783, 'cat_random_strength': 0.0760351005623097}. Best is trial 24 with value: 0.8201615286122328.
# [I 2025-03-16 12:29:38,770] Trial 37 finished with value: 0.813158672313602 and parameters: {'xgb_learning_rate': 0.06551235202552415, 'xgb_max_depth': 9, 'xgb_subsample': 0.9994629176554529, 'xgb_colsample_bytree': 0.8933849131709772, 'xgb_n_estimators': 245, 'cat_learning_rate': 0.011480849767006435, 'cat_depth': 9, 'cat_iterations': 308, 'cat_l2_leaf_reg': 0.012865380300520793, 'cat_subsample': 0.5520735693562324, 'cat_random_strength': 0.042250664149496395}. Best is trial 24 with value: 0.8201615286122328.
# [I 2025-03-16 12:29:44,843] Trial 38 finished with value: 0.8103614695163991 and parameters: {'xgb_learning_rate': 0.037474372039142737, 'xgb_max_depth': 10, 'xgb_subsample': 0.9179051945628789, 'xgb_colsample_bytree': 0.9308903129035502, 'xgb_n_estimators': 139, 'cat_learning_rate': 0.03680067038945754, 'cat_depth': 8, 'cat_iterations': 235, 'cat_l2_leaf_reg': 0.005161727995668281, 'cat_subsample': 0.6895638762562077, 'cat_random_strength': 0.08221440415116477}. Best is trial 24 with value: 0.8201615286122328.
# [I 2025-03-16 12:29:48,206] Trial 39 finished with value: 0.790672707574116 and parameters: {'xgb_learning_rate': 0.0021541468897819764, 'xgb_max_depth': 12, 'xgb_subsample': 0.9389340741454236, 'xgb_colsample_bytree': 0.9552190615891674, 'xgb_n_estimators': 213, 'cat_learning_rate': 0.000468009157092135, 'cat_depth': 4, 'cat_iterations': 341, 'cat_l2_leaf_reg': 0.0019431496834480734, 'cat_subsample': 0.7335953693753182, 'cat_random_strength': 0.0002549564608396379}. Best is trial 24 with value: 0.8201615286122328.
# [I 2025-03-16 12:29:52,960] Trial 40 finished with value: 0.6165763813651137 and parameters: {'xgb_learning_rate': 0.00032181539095289043, 'xgb_max_depth': 11, 'xgb_subsample': 0.8901068350886477, 'xgb_colsample_bytree': 0.6516460305848678, 'xgb_n_estimators': 288, 'cat_learning_rate': 0.0009125649902722893, 'cat_depth': 7, 'cat_iterations': 261, 'cat_l2_leaf_reg': 0.031156990712948137, 'cat_subsample': 0.5892449243407396, 'cat_random_strength': 0.052891540784481106}. Best is trial 24 with value: 0.8201615286122328.
# [I 2025-03-16 12:30:09,453] Trial 41 finished with value: 0.813158672313602 and parameters: {'xgb_learning_rate': 0.06731756654691284, 'xgb_max_depth': 11, 'xgb_subsample': 0.8341783790627645, 'xgb_colsample_bytree': 0.9110543894635774, 'xgb_n_estimators': 127, 'cat_learning_rate': 0.004771831830168296, 'cat_depth': 10, 'cat_iterations': 296, 'cat_l2_leaf_reg': 0.05494574063752555, 'cat_subsample': 0.6479366962318353, 'cat_random_strength': 0.07665080713303428}. Best is trial 24 with value: 0.8201615286122328.
# [I 2025-03-16 12:30:24,983] Trial 42 finished with value: 0.8089333202009257 and parameters: {'xgb_learning_rate': 0.03147149779869301, 'xgb_max_depth': 11, 'xgb_subsample': 0.9526560575706627, 'xgb_colsample_bytree': 0.6953515024350445, 'xgb_n_estimators': 187, 'cat_learning_rate': 0.010547679980936973, 'cat_depth': 10, 'cat_iterations': 301, 'cat_l2_leaf_reg': 0.01711364063854173, 'cat_subsample': 0.6521188520682865, 'cat_random_strength': 0.07066602256601712}. Best is trial 24 with value: 0.8201615286122328.
# [I 2025-03-16 12:30:35,827] Trial 43 finished with value: 0.813138973702354 and parameters: {'xgb_learning_rate': 0.04513349603448395, 'xgb_max_depth': 12, 'xgb_subsample': 0.8693617010529969, 'xgb_colsample_bytree': 0.8282463361034902, 'xgb_n_estimators': 152, 'cat_learning_rate': 0.001485718989424552, 'cat_depth': 9, 'cat_iterations': 370, 'cat_l2_leaf_reg': 0.009003226854133576, 'cat_subsample': 0.7045501653650785, 'cat_random_strength': 0.06636413957786935}. Best is trial 24 with value: 0.8201615286122328.
# [I 2025-03-16 12:30:51,612] Trial 44 finished with value: 0.8159657244164287 and parameters: {'xgb_learning_rate': 0.0759370467951669, 'xgb_max_depth': 10, 'xgb_subsample': 0.9050350490177226, 'xgb_colsample_bytree': 0.9707944055794688, 'xgb_n_estimators': 116, 'cat_learning_rate': 0.0024794823076234778, 'cat_depth': 10, 'cat_iterations': 321, 'cat_l2_leaf_reg': 0.034828055882368154, 'cat_subsample': 0.6125478018280092, 'cat_random_strength': 0.05971870356514536}. Best is trial 24 with value: 0.8201615286122328.
# [I 2025-03-16 12:31:07,250] Trial 45 finished with value: 0.8117600709150006 and parameters: {'xgb_learning_rate': 0.07895321471796159, 'xgb_max_depth': 10, 'xgb_subsample': 0.8977962704863297, 'xgb_colsample_bytree': 0.9569982399231375, 'xgb_n_estimators': 92, 'cat_learning_rate': 0.00231811198858503, 'cat_depth': 10, 'cat_iterations': 338, 'cat_l2_leaf_reg': 0.03262966318758882, 'cat_subsample': 0.6093104906721482, 'cat_random_strength': 0.060904217226018596}. Best is trial 24 with value: 0.8201615286122328.
# [I 2025-03-16 12:31:19,996] Trial 46 finished with value: 0.8047473653107456 and parameters: {'xgb_learning_rate': 0.06781417265520336, 'xgb_max_depth': 12, 'xgb_subsample': 0.9892182241862753, 'xgb_colsample_bytree': 0.9833795625053574, 'xgb_n_estimators': 112, 'cat_learning_rate': 0.0002398389596961559, 'cat_depth': 9, 'cat_iterations': 396, 'cat_l2_leaf_reg': 0.0009100971526477245, 'cat_subsample': 0.5623208509079113, 'cat_random_strength': 0.04454566400330773}. Best is trial 24 with value: 0.8201615286122328.
# [I 2025-03-16 12:31:36,914] Trial 47 finished with value: 0.8075248694967005 and parameters: {'xgb_learning_rate': 0.09759682394348353, 'xgb_max_depth': 9, 'xgb_subsample': 0.97132195548395, 'xgb_colsample_bytree': 0.6139066298220289, 'xgb_n_estimators': 86, 'cat_learning_rate': 0.0010612059571031547, 'cat_depth': 10, 'cat_iterations': 361, 'cat_l2_leaf_reg': 0.00041863033945157657, 'cat_subsample': 0.5981157066182274, 'cat_random_strength': 0.058921425227018716}. Best is trial 24 with value: 0.8201615286122328.
# [I 2025-03-16 12:31:42,913] Trial 48 finished with value: 0.6165763813651137 and parameters: {'xgb_learning_rate': 0.0007809667571988879, 'xgb_max_depth': 5, 'xgb_subsample': 0.8181324201046994, 'xgb_colsample_bytree': 0.881965028158702, 'xgb_n_estimators': 140, 'cat_learning_rate': 0.006064444826253187, 'cat_depth': 8, 'cat_iterations': 322, 'cat_l2_leaf_reg': 0.00024941615960041575, 'cat_subsample': 0.5264687711000555, 'cat_random_strength': 0.06615385346078212}. Best is trial 24 with value: 0.8201615286122328.
# [I 2025-03-16 12:31:47,469] Trial 49 finished with value: 0.8089628681177977 and parameters: {'xgb_learning_rate': 0.017205570549045535, 'xgb_max_depth': 8, 'xgb_subsample': 0.8945321627530955, 'xgb_colsample_bytree': 0.9326273560124952, 'xgb_n_estimators': 165, 'cat_learning_rate': 0.04387735451943765, 'cat_depth': 6, 'cat_iterations': 425, 'cat_l2_leaf_reg': 0.026033796154506333, 'cat_subsample': 0.5251213271490294, 'cat_random_strength': 0.05265914138364014}. Best is trial 24 with value: 0.8201615286122328.
# {'xgb_learning_rate': 0.04715531384031086, 'xgb_max_depth': 11, 'xgb_subsample': 0.6842012541367772, 'xgb_colsample_bytree': 0.7063265941151023, 'xgb_n_estimators': 264, 'cat_learning_rate': 0.002058033302219121, 'cat_depth': 10, 'cat_iterations': 316, 'cat_l2_leaf_reg': 0.05716294723972189, 'cat_subsample': 0.7103322975984013, 'cat_random_strength': 0.05574267025961141}

# %% [markdown]
# # Train With Best Parameters>

# %%
best_xgb_params = {
        "learning_rate": study.best_params['xgb_learning_rate'],
        "max_depth": study.best_params['xgb_max_depth'],
        "subsample": study.best_params['xgb_subsample'],
        "colsample_bytree": study.best_params['xgb_colsample_bytree'],
        "n_estimators": study.best_params['xgb_n_estimators'],
}
best_cat_params = {
        "learning_rate": study.best_params['cat_learning_rate'],
        "depth": study.best_params['cat_depth'],
        "iterations": study.best_params['cat_iterations'],
        "l2_leaf_reg": study.best_params['cat_l2_leaf_reg'],
        "subsample": study.best_params['cat_subsample'],
        "random_strength": study.best_params['cat_random_strength'],
}    

#Final Model
xgb_2 = XGBClassifier(**best_xgb_params, use_label_encoder=False, eval_metric='logloss')
cat_2 = CatBoostClassifier(**best_cat_params, verbose=0)

pipeline_2 = Pipeline([
    ("preprocessor", preprocessor),
    ("classifier",VotingClassifier(estimators=[('xgb', xgb_2),
                                               ('cat', cat_2)],
                                   voting='hard'))
])

pipeline_2.fit(X_train,y_train)
test_score = pipeline_2.score(X_test,y_test)
print(f"The Model Accuracy is {test_score}")
# Out:
# The Model Accuracy is 0.8268156424581006

# %% [markdown]
# # Predicitions For The Test set

# %%
y_pred = pipeline_2.predict(test_df)

result = pd.DataFrame()
result['PassengerId'] = test_Id
result['Survived'] = y_pred
result.to_csv('submission.csv', index=False)
